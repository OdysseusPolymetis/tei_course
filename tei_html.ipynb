# %% [markdown]
# <a href="https://colab.research.google.com/github/OdysseusPolymetis/tei_course/blob/main/tei_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/OdysseusPolymetis/alto2tei_segmonto.git

# %%
# !apt-get install xsltproc

# %%
from google.colab import files
import os
uploaded = files.upload()

# %%
input_file = list(uploaded.keys())[0]

base_name = os.path.splitext(input_file)[0]
output_file = f"{base_name}.html"

# %%
# !xsltproc /content/alto2tei_segmonto/xsl/tei2html_robust.xsl "/content/{input_file}" > "/content/{output_file}"
